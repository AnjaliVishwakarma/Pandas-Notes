# %% [markdown]
# Link for Pandas Documentation
#
# https://www.w3schools.com/python/pandas/default.asp

# %% [markdown]
# # Data Science
# * Data Science and Data Analytics is a process of analyzing large set of data points to get answer on questions related to that dataset.
# * Pandas is a python module that make data science easy and effective.

# %%
import pandas as pd

# %%
df = pd.read_csv('weather.csv')
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
# df
rows, columns = df.shape
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
rows
# Out:
# 366

# %%
columns
# Out:
# 22

# %%
df.head(5)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.tail(5)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
df[10:16]
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 10      9.1     25.2       0.0          4.2      11.9           N
# 11      8.5     27.3       0.2          7.2      12.5           E
# 12     10.1     27.9       0.0          7.2      13.0         WNW
# 13     12.1     30.9       0.0          6.2      12.4          NW
# 14     10.1     31.2       0.0          8.8      13.1          NW
# 15     12.4     32.1       0.0          8.4      11.1           E
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 10           30.0         SE         NW           6.0  ...           34
# 11           41.0          E         NW           2.0  ...           35
# 12           30.0          S         NW           6.0  ...           29
# 13           44.0        WNW          W           7.0  ...           20
# 14           41.0          S          W           6.0  ...           16
# ...

# %%
df.MinTemp
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
df['MinTemp'].max()
# Out:
# 20.9

# %%
df['MaxTemp']
# Out:
# 0      24.3
# 1      26.9
# 2      23.4
# 3      15.5
# 4      16.1
#        ...
# 361    30.7
# 362    28.4
# 363    19.9
# 364    26.9
# 365    30.2
# Name: MaxTemp, Length: 366, dtype: float64

# %%
df['MaxTemp'].max()
# Out:
# 35.8

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df[['MinTemp', 'MaxTemp','Temp9am',
       'Temp3pm']]
# Out:
#      MinTemp  MaxTemp  Temp9am  Temp3pm
# 0        8.0     24.3     14.4     23.6
# 1       14.0     26.9     17.5     25.7
# 2       13.7     23.4     15.4     20.2
# 3       13.3     15.5     13.5     14.1
# 4        7.6     16.1     11.1     15.4
# ..       ...      ...      ...      ...
# 361      9.0     30.7     20.4     30.0
# 362      7.1     28.4     17.2     28.2
# 363     12.5     19.9     14.5     18.3
# 364     12.5     26.9     15.8     25.9
# 365     12.3     30.2     23.8     28.6
#
# [366 rows x 4 columns]

# %%
df[['MinTemp', 'MaxTemp','Temp9am',
       'Temp3pm']].max()
# Out:
# MinTemp    20.9
# MaxTemp    35.8
# Temp9am    24.7
# Temp3pm    34.5
# dtype: float64

# %%
df[[ 'Rainfall', 'Evaporation', 'Sunshine']]
# Out:
#      Rainfall  Evaporation  Sunshine
# 0         0.0          3.4       6.3
# 1         3.6          4.4       9.7
# 2         3.6          5.8       3.3
# 3        39.8          7.2       9.1
# 4         2.8          5.6      10.6
# ..        ...          ...       ...
# 361       0.0          7.6      12.1
# 362       0.0         11.6      12.7
# 363       0.0          8.4       5.3
# 364       0.0          5.0       7.1
# 365       0.0          6.0      12.6
#
# [366 rows x 3 columns]

# %%
df[[ 'Rainfall', 'Evaporation', 'Sunshine']].max()
# Out:
# Rainfall       39.8
# Evaporation    13.8
# Sunshine       13.6
# dtype: float64

# %%
df[[ 'Rainfall', 'Evaporation', 'Sunshine']].min()
# Out:
# Rainfall       0.0
# Evaporation    0.2
# Sunshine       0.0
# dtype: float64

# %%
df[[ 'Rainfall', 'Evaporation', 'Sunshine']].mean()
# Out:
# Rainfall       1.428415
# Evaporation    4.521858
# Sunshine       7.909366
# dtype: float64

# %%
df[['WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
       'WindSpeed9am', 'WindSpeed3pm']]
# Out:
#     WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0            NW           30.0         SW         NW           6.0
# 1           ENE           39.0          E          W           4.0
# 2            NW           85.0          N        NNE           6.0
# 3            NW           54.0        WNW          W          30.0
# 4           SSE           50.0        SSE        ESE          20.0
# ..          ...            ...        ...        ...           ...
# 361         NNW           76.0        SSE         NW           7.0
# 362           N           48.0        NNW        NNW           2.0
# 363         ESE           43.0        ENE        ENE          11.0
# 364          NW           46.0        SSW        WNW           6.0
# 365          NW           78.0         NW        WNW          31.0
#
#      WindSpeed3pm
# 0              20
# 1              17
# 2               6
# 3              24
# 4              28
# ..            ...
# 361            50
# ...

# %%
df[['WindGustSpeed','WindSpeed9am', 'WindSpeed3pm']].max()
# Out:
# WindGustSpeed    98.0
# WindSpeed9am     41.0
# WindSpeed3pm     52.0
# dtype: float64

# %%
df[['WindGustSpeed','WindSpeed9am', 'WindSpeed3pm']].min()
# Out:
# WindGustSpeed    13.0
# WindSpeed9am      0.0
# WindSpeed3pm      0.0
# dtype: float64

# %%
df[['WindGustDir','WindDir9am','WindDir3pm']]
# Out:
#     WindGustDir WindDir9am WindDir3pm
# 0            NW         SW         NW
# 1           ENE          E          W
# 2            NW          N        NNE
# 3            NW        WNW          W
# 4           SSE        SSE        ESE
# ..          ...        ...        ...
# 361         NNW        SSE         NW
# 362           N        NNW        NNW
# 363         ESE        ENE        ENE
# 364          NW        SSW        WNW
# 365          NW         NW        WNW
#
# [366 rows x 3 columns]

# %%
# df[['WindGustDir','WindDir9am','WindDir3pm']]
df.set_index('WindGustDir',inplace=True)

# %%
df
# Out:
#              MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# WindGustDir
# NW               8.0     24.3       0.0          3.4       6.3           30.0
# ENE             14.0     26.9       3.6          4.4       9.7           39.0
# NW              13.7     23.4       3.6          5.8       3.3           85.0
# NW              13.3     15.5      39.8          7.2       9.1           54.0
# SSE              7.6     16.1       2.8          5.6      10.6           50.0
# ...              ...      ...       ...          ...       ...            ...
# NNW              9.0     30.7       0.0          7.6      12.1           76.0
# N                7.1     28.4       0.0         11.6      12.7           48.0
# ESE             12.5     19.9       0.0          8.4       5.3           43.0
# NW              12.5     26.9       0.0          5.0       7.1           46.0
# NW              12.3     30.2       0.0          6.0      12.6           78.0
#
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#      index WindGustDir  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        0          NW      8.0     24.3       0.0          3.4       6.3
# 1        1         ENE     14.0     26.9       3.6          4.4       9.7
# 2        2          NW     13.7     23.4       3.6          5.8       3.3
# 3        3          NW     13.3     15.5      39.8          7.2       9.1
# 4        4         SSE      7.6     16.1       2.8          5.6      10.6
# ..     ...         ...      ...      ...       ...          ...       ...
# 361    361         NNW      9.0     30.7       0.0          7.6      12.1
# 362    362           N      7.1     28.4       0.0         11.6      12.7
# 363    363         ESE     12.5     19.9       0.0          8.4       5.3
# 364    364          NW     12.5     26.9       0.0          5.0       7.1
# 365    365          NW     12.3     30.2       0.0          6.0      12.6
#
#      WindGustSpeed WindDir9am WindDir3pm  ...  Humidity3pm  Pressure9am  \
# ...

# %%
df.describe()
# Out:
#             index     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count  366.000000  366.000000  366.000000  366.000000   366.000000
# mean   182.500000    7.265574   20.550273    1.428415     4.521858
# std    105.799338    6.025800    6.690516    4.225800     2.669383
# min      0.000000   -5.300000    7.600000    0.000000     0.200000
# 25%     91.250000    2.300000   15.025000    0.000000     2.200000
# 50%    182.500000    7.450000   19.650000    0.000000     4.200000
# 75%    273.750000   12.500000   25.500000    0.200000     6.400000
# max    365.000000   20.900000   35.800000   39.800000    13.800000
#
#          Sunshine  WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# count  363.000000     364.000000    359.000000    366.000000   366.000000
# mean     7.909366      39.840659      9.651811     17.986339    72.035519
# std      3.481517      13.059807      7.951929      8.856997    13.137058
# ...

# %%
df[df.MinTemp>=20]
# Out:
#     index WindGustDir  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 72     72          SW     20.9     35.7       0.0         13.8       6.9
#
#     WindGustSpeed WindDir9am WindDir3pm  ...  Humidity3pm  Pressure9am  \
# 72           50.0          E        WNW  ...           28       1007.6
#
#     Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 72       1003.0         7         2     23.6     34.0         No      2.0
#
#     RainTomorrow
# 72           Yes
#
# [1 rows x 23 columns]

# %%
df[df.MaxTemp>=35]
# Out:
#      index WindGustDir  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 59      59           E     15.4     35.0       0.0          9.6      13.0
# 62      62         ESE     14.3     35.0       0.0          7.6      10.5
# 71      71         SSE     17.5     35.8       0.0          9.4      13.3
# 72      72          SW     20.9     35.7       0.0         13.8       6.9
# 135    135          SE     13.8     35.2       0.0          6.4      11.2
#
#      WindGustSpeed WindDir9am WindDir3pm  ...  Humidity3pm  Pressure9am  \
# 59            39.0        SSW        ESE  ...           18       1017.4
# 62            41.0        ESE        WSW  ...           14       1012.6
# 71            57.0        NNW         NW  ...           24       1011.8
# 72            50.0          E        WNW  ...           28       1007.6
# 135           48.0         SE        ESE  ...           15       1022.5
#
#      Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
df[df.MaxTemp>=35]
